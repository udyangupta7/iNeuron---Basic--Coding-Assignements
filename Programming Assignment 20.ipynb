# %% [markdown]
# # Programming Assignment 20
#
# #### Q1:Create a function that takes a list of strings and integers, and filters out the list so that it returns a list of integers only.
#
# Ex:
#
# i. filter_list([1, 2, 3, "a", "b", 4]) ➞ [1, 2, 3, 4]
#
# ii. filter_list(["A", 0, "Edabit", 1729, "Python", "1729"]) ➞ [0, 1729]
#
# iii. filter_list(["Nothing", "here"]) ➞ []
#
# #### A1:

# %%
filter_list = []
l = ["A", 0, 3, "wered", 456,"Edabit", 1729, "Python", "1729"]
for i in l: 
    if type(i) == int: filter_list.append(i)
print(filter_list)
# Out:
# [0, 3, 456, 1729]

# %% [markdown]
# #### Q2: Given a list of numbers, create a function which returns the list but with each element's index in the list added to itself. This means you add 0 to the number at index 0, add 1 to the number at index 1, etc...
#
# Ex:
#
# i. add_indexes([0, 0, 0, 0, 0]) ➞ [0, 1, 2, 3, 4]
#
# ii. add_indexes([1, 2, 3, 4, 5]) ➞ [1, 3, 5, 7, 9]
#
# iii. add_indexes([5, 4, 3, 2, 1]) ➞ [5, 5, 5, 5, 5]
#
# #### A2:

# %%
add_indexes = []
upper = int(input("Enter the range for the list: "))
l1 =[int(input("Enter a number: ")) for x in range(upper)]
for value in l1:
    c = value + l1.index(value)
    add_indexes.append(c)
print(add_indexes)
# Out:
# Enter the range for the list: 5
# Enter a number: 5
# Enter a number: 4
# Enter a number: 3
# Enter a number: 2
# Enter a number: 1
# [5, 5, 5, 5, 5]

# %% [markdown]
# #### Q3: Create a function that takes the height and radius of a cone as arguments and returns the volume of the cone rounded to the nearest hundredth. See the resources tab for the formula.

# %% [markdown]
# ![Screenshot%202021-10-18%20at%2012.11.07%20AM.png](attachment:Screenshot%202021-10-18%20at%2012.11.07%20AM.png)

# %% [markdown]
#                The volume of a cone is:

# %% [markdown]
# ![Screenshot%202021-10-18%20at%2012.14.42%20AM.png](attachment:Screenshot%202021-10-18%20at%2012.14.42%20AM.png)

# %% [markdown]
# Ex:
# cone_volume(h,r)
#
# i. cone_volume(3, 2) ➞ 12.57
#
# ii. cone_volume(15, 6) ➞ 565.49
#
# iii. cone_volume(18, 0) ➞ 0

# %%
def cone_volume():
    import math
    radius = int(input("Enter the radius for the cone: "))
    height = int(input("Enter the radius for the cone: "))
    volume = math.pi * radius * radius * (height/3)
    print(round(volume,2))
cone_volume()
# Out:
# Enter the radius for the cone: 0
# Enter the radius for the cone: 18
# 0.0

# %% [markdown]
# #### Q4: This Triangular Number Sequence is generated from a pattern of dots that form a triangle. The first 5 numbers of the sequence, or dots, are:  1, 3, 6, 10, 15
#
# This means that the first triangle has just one dot, the second one has three dots, the third one has 6 dots and so on.
# Write a function that gives the number of dots with its corresponding triangle number of the sequence.
#
# Ex:
#
# i. triangle(1) ➞ 1
#
# ii. triangle(6) ➞ 21
#
# iii. triangle(215) ➞ 23220
#
# #### A4:

# %%
def triangle():
    dot = int(input("Enter the total number of dots in the triangle: "))
    print("The triangular number for",dot,"number of triangles is - ",((dot*(dot+1)/2)))
triangle()
# Out:
# Enter the total number of dots in the triangle: 215
# The triangular number for 215 number of triangles is -  23220.0

# %% [markdown]
# #### Q5: Create a function that takes a list of numbers between 1 and 10 (excluding one number) and returns the missing number.
#
# Ex:
#
# i. missing_num([1, 2, 3, 4, 6, 7, 8, 9, 10]) ➞ 5
#
# ii. missing_num([7, 2, 3, 6, 5, 9, 1, 4, 8]) ➞ 10
#
# iii. missing_num([10, 5, 1, 2, 4, 6, 8, 3, 9]) ➞ 7
#
# #### A5:

# %%
def missing_num(arr):
    arr = []
    for i in range(9):
        while True:
            num = int(input("Enter a number: "))
            if num < 0 or num > 10: print("Enter a number betweeb 0-10")
            else: break
        arr.append(num)
    n = len(arr)
    m = n + 1
    total = m * (m + 1) // 2
    return total - sum(arr)
arr = [1, 2, 3, 4, 5, 7, 8, 9, 10]
print('The missing number is', missing_num(arr))
# Out:
# Enter a number: 1
# Enter a number: 2
# Enter a number: 3
# Enter a number: 4
# Enter a number: 5
# Enter a number: 7
# Enter a number: 8
# Enter a number: 9
# Enter a number: 10
# The missing number is 6
